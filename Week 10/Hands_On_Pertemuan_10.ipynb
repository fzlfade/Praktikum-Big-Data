# %% [markdown]
# # Hands-On Pertemuan 10: Implementasi NoSQL Database - MongoDB

# %% [markdown]
# ## Tujuan:
# - Mengenal konsep dasar dan pengimplementasian database NoSQL, khususnya MongoDB.
# - Melakukan berbagai operasi dasar pada MongoDB untuk analisis data.
# - Mengasah keterampilan dalam menulis query yang lebih kompleks.

# %% [markdown]
# ### 1. Menghubungkan ke Database MongoDB
# - **Tugas 1**: Pastikan MongoDB telah terpasang dan berjalan. Hubungkan ke MongoDB lokal.

# %%
from pymongo import MongoClient

# Inisialisasi client dan koneksi ke database
client = MongoClient('mongodb://localhost:27017/')
db = client['company_db']
collection = db['employees']

# Contoh untuk memastikan koneksi
print('Connected to MongoDB')
# Out:
# Connected to MongoDB

# %% [markdown]
# ### 2. Operasi CRUD Dasar
# - **Tugas 2**: Insert, Update, dan Delete data pada koleksi `employees`.

# %%
# Contoh Insert Data
employee_data = {
    'name': 'Faizal',
    'department': 'Human Resources',
    'age': 21,
    'salary': 45000
}
collection.insert_one(employee_data)
print('Data inserted')

# Tugas: Insert beberapa data tambahan, lakukan update, serta delete data
# Out:
# Data inserted

# %%
# Contoh Update Data
employee_data = {'salary': 45000}
new_values = {'$set': {'salary': 50000}}

collection.update_one(employee_data, new_values)
print('Data updated')
# Out:
# Data updated

# %%
# Contoh Delete Data
employee_data = {'name': 'Alice Wonderland'}

collection.delete_one(employee_data)
print('Data deleted')
# Out:
# Data deleted

# %%
# Contoh Query Data
for employee in collection.find():
    print(employee)
# Out:
# {'_id': ObjectId('672181dd847ded794f657b4d'), 'name': 'Alice', 'department': 'Finance', 'age': 29, 'salary': 4500}
# {'_id': ObjectId('6721961200cbcc46853038fb'), 'name': 'Faizal', 'department': 'Human Resources', 'age': 21, 'salary': 50000}

# %% [markdown]
# ### 3. Query Lebih Kompleks Menggunakan Aggregation
# - **Tugas 3**: Terapkan aggregation untuk menghitung rata-rata gaji per departemen.

# %%
# Query Aggregation untuk mencari rata-rata gaji per departemen
pipeline = [
    {'$group': {'_id': '$department', 'average_salary': {'$avg': '$salary'}}}
]
for result in collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Human Resources', 'average_salary': 50000.0}
# {'_id': 'Finance', 'average_salary': 4500.0}

# %% [markdown]
# ### 4. Latihan Tambahan
# - **Latihan 4.1**: Buatlah koleksi baru `products` dan masukkan data produk (minimal 10 produk).
# - **Latihan 4.2**: Lakukan query untuk menemukan produk dengan harga di atas rata-rata.
# - **Latihan 4.3**: Buatlah aggregation pipeline untuk menghitung total produk dalam setiap kategori.

# %%
collection = db['products']

# Contoh untuk memastikan koneksi
print('Connected to MongoDB')
# Out:
# Connected to MongoDB

# %%
products_data = [
    {'name': 'Apple', 'Price': 1, 'Quantity': 200},
    {'name': 'Beef ', 'Price': 20, 'Quantity': 50},
    {'name': 'Chicken Nugget', 'Price': 10, 'Quantity': 1000},
    {'name': 'Donut', 'Price': 1, 'Quantity': 100},
    {'name': 'Egg', 'Price': 0.5, 'Quantity': 300},
    {'name': 'Fish', 'Price': 3, 'Quantity': 50},
    {'name': 'Grapes', 'Price': 0.1, 'Quantity': 1000},
    {'name': 'Honey', 'Price': 2, 'Quantity': 100},
    {'name': 'Instant Noodles', 'Price': 1, 'Quantity': 2000},
    {'name': 'Jelly', 'Price': 2, 'Quantity': 500,} 
]
collection.insert_many(products_data)
print('Data inserted')
# Out:
# Data inserted

# %%
for products in collection.find():
    print(products)
# Out:
# {'_id': ObjectId('67219ac100cbcc4685303911'), 'name': 'Apple', 'Price': 1, 'Quantity': 200}
# {'_id': ObjectId('67219ac100cbcc4685303912'), 'name': 'Beef ', 'Price': 20, 'Quantity': 50}
# {'_id': ObjectId('67219ac100cbcc4685303913'), 'name': 'Chicken Nugget', 'Price': 10, 'Quantity': 1000}
# {'_id': ObjectId('67219ac100cbcc4685303914'), 'name': 'Donut', 'Price': 1, 'Quantity': 100}
# {'_id': ObjectId('67219ac100cbcc4685303915'), 'name': 'Egg', 'Price': 0.5, 'Quantity': 300}
# {'_id': ObjectId('67219ac100cbcc4685303916'), 'name': 'Fish', 'Price': 3, 'Quantity': 50}
# {'_id': ObjectId('67219ac100cbcc4685303917'), 'name': 'Grapes', 'Price': 0.1, 'Quantity': 1000}
# {'_id': ObjectId('67219ac100cbcc4685303918'), 'name': 'Honey', 'Price': 2, 'Quantity': 100}
# {'_id': ObjectId('67219ac100cbcc4685303919'), 'name': 'Instant Noodles', 'Price': 1, 'Quantity': 2000}
# {'_id': ObjectId('67219ac100cbcc468530391a'), 'name': 'Jelly', 'Price': 2, 'Quantity': 500}

# %%
pipeline = [
    {'$group': {'_id': '$department', 'average_salary': {'$avg': '$salary'}}}
]
for result in collection.aggregate(pipeline):
    print(result)

# %% [markdown]
# ### 5. Tugas
# - **Tugas 1**: Cari 5 karyawan dengan gaji tertinggi dalam setiap departemen, gunakan query atau aggregation yang sesuai.
# - **Tugas 2**: Buatlah skenario di mana Anda harus menghapus karyawan yang berusia di bawah 25 tahun dari database.
# - **Tugas 3**: Buatlah laporan ringkas (menggunakan MongoDB query) yang menghitung total gaji karyawan di setiap departemen, serta rata-rata umur karyawan.
